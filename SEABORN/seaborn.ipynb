# %%
import seaborn as sns

# %%
#Basic plotting with seaborn
tips_df=sns.load_dataset("tips")
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
type(tips_df)
# Out:
# pandas.core.frame.DataFrame

# %%
#Creating a scatter plot

# %%
import matplotlib.pyplot as plt
sns.scatterplot(x="total_bill",y="tip",hue="time",data=tips_df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
##Line Plot
sns.lineplot(x="size",y="total_bill",data=tips_df)
plt.title("SIZE vs TOTAL BILL")
plt.show()

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
##categorical plots
##bar plot
sns.barplot(x="day",y="total_bill",data=tips_df)
plt.title("BAR PLOT OF TOTAL BILL BY DAY")
plt.show()

# %%
##categorical plots
##bar plot
sns.barplot(x="smoker",y="total_bill",data=tips_df)
plt.title("BAR PLOT OF TOTAL BILL BY SMOKER")
plt.xlabel("SMOKER")
plt.ylabel("TOTAL BILL")
plt.show()

# %%
##BOX PLOT
sns.boxplot(x="day",y="total_bill",data=tips_df)
plt.show()

# %%
##VIOLIN PLOT
sns.violinplot(x="day",y="total_bill",data=tips_df)
plt.show()

# %%
##HISTOGRAMS
sns.histplot(x="total_bill",bins=7,data=tips_df,kde=True)
plt.show()

# %%
sns.kdeplot(x="total_bill",data=tips_df,fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
##Pairplot
#gives the relation between each and every attribute with other attribute
#only foe numerical variables and categorical
sns.pairplot(tips_df)

# %%
#HEAT MAP
## realted to correlation 
corr=tips_df[["total_bill","tip",'size']].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,cmap="coolwarm",annot=True)
# Out:
# <Axes: >

# %%
import pandas as pd
sales_df=pd.read_csv("D:\CompleteMLAndNlpBootcamp\MATPLOTLIB\sales_data.csv")
sales_df.head(5)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\C'
# <>:2: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\zaynb\AppData\Local\Temp\ipykernel_13880\1993931404.py:2: SyntaxWarning: invalid escape sequence '\C'
#   sales_df=pd.read_csv("D:\CompleteMLAndNlpBootcamp\MATPLOTLIB\sales_data.csv")
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# ...

# %%
##total sales by product
plt.figure(figsize=(10,6))
sns.barplot(x="Product Category",y="Total Revenue",data=sales_df,estimator=sum)
# Out:
# <Axes: xlabel='Product Category', ylabel='Total Revenue'>

# %%
##total sales by Region
plt.figure(figsize=(10,6))
sns.barplot(x="Region",y="Total Revenue",data=sales_df,estimator=sum)
# Out:
# <Axes: xlabel='Region', ylabel='Total Revenue'>

# %%
sales_df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
##total sales by product
plt.figure(figsize=(6,5))
#sns.barplot(x="Region",y="Payment Method",data=sales_df,estimator=sum)
sns.histplot(x="Payment Method",bins=5,data=sales_df)
# Out:
# <Axes: xlabel='Payment Method', ylabel='Count'>
